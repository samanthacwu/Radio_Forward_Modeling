# %%
import numpy as np
import matplotlib.pyplot as plt
import os 

plt.style.use('/Users/samwu/codes/current_projects/RadioTDEFlares/plot_styles.mplstyle_new')

# %%
km_s = 1e5 #* cm/s
G = 6.67430e-8
Msun = 1.989e33
Lsun = 3.828e33
Rsun = 6.96e10

secinyear = 3.154e7
secinday = 86400

# %% [markdown]
# ## check loading data

# %%
rhoISM_vals = [1000,1e4,1e5,1e6,5e6] #in secinyear

for rhoISM in rhoISM_vals:
    print(rhoISM)
    shell_data = np.loadtxt('../shell_propagation/shell_evolution_rhoISM_%ge-24_cgs.txt' % rhoISM)
    time = shell_data[:,0] #s
    rsh = shell_data[:,1] #cm
    vsh = shell_data[:,2] #cm/s
    # deltav_1 = shell_data[:,3] #cm/s
    deltav_2 = shell_data[:,3] #cm/s
    rho_const = shell_data[:,4] #g/cm^3
    rhofl_2 = shell_data[:,5] #g/cm^3
    int_rhofl_1_sq_dr = shell_data[:,6] #g^2/cm^5 
    print('initial time (yr)',time[0]/secinyear, 'final time (yr)', time[-1]/secinyear)
    plt.figure()
    plt.plot(time, vsh,color='black',ls=':',label=r'$v_{\rm sh}$')
    # plt.plot(time, deltav_1,color='crimson',label=r'$\Delta v_{1}$')
    plt.plot(time, deltav_2,color='dodgerblue',label=r'$\Delta v_{2}$')
    plt.xlim(1e5,1e10)
    plt.ylim(1e6,1e10)
    plt.xlabel('Time (s)')
    plt.ylabel('Shell Velocity (cm/s)')
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    plt.grid(which='both',linestyle=':')
    plt.title('rho_ISM = %ge-24 g/cm3' % rhoISM)
# Out:
# 1000
# initial time (yr) 0.10016544705136335 final time (yr) 100.14579264426125
# 10000.0
# initial time (yr) 0.10016968611287254 final time (yr) 100.1389790741915
# 100000.0
# initial time (yr) 0.10018282181357008 final time (yr) 100.14064362714014
# 1000000.0
# initial time (yr) 0.1002219435637286 final time (yr) 100.06823398858592
# 5000000.0
# initial time (yr) 0.10028450221940394 final time (yr) 100.09526949904883

# %%
rhoISM_vals = [1000,1e4,1e5,1e6,5e6] #in secinyear

for rhoISM in rhoISM_vals:
    print(rhoISM)
    shell_data = np.loadtxt('../shell_propagation/shell_evolution_rhoISM_%ge-24_cgs.txt' % rhoISM)
    time = shell_data[:,0] #s
    rsh = shell_data[:,1] #cm
    vsh = shell_data[:,2] #cm/s
    # deltav_1 = shell_data[:,3] #cm/s
    deltav_2 = shell_data[:,3] #cm/s
    rho_const = shell_data[:,4] #g/cm^3
    rhofl_2 = shell_data[:,5] #g/cm^3
    int_rhofl_1_sq_dr = shell_data[:,6] #g^2/cm^5 
    print('initial time (yr)',time[0]/secinyear, 'final time (yr)', time[-1]/secinyear)
    plt.figure()
    plt.plot(time, vsh,color='black',ls=':',label=r'$v_{\rm sh}$')
    # plt.plot(time, vsh-deltav_1,color='crimson',label=r'$v_{1}$')
    plt.plot(time, deltav_2+vsh,color='dodgerblue',label=r'$v_{2}$')
    plt.xlabel('Time (s)')
    plt.ylabel('Shell Velocity (cm/s)')
    plt.xlim(1e5,1e10)
    # plt.ylim(1e6,1e10)
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    plt.grid(which='both',linestyle=':')
    plt.title('rho_ISM = %ge-24 g/cm3' % rhoISM)

# plt.savefig('shell_velocity.png',bbox_inches='tight')
# Out:
# 1000
# initial time (yr) 0.10016544705136335 final time (yr) 100.14579264426125
# 10000.0
# initial time (yr) 0.10016968611287254 final time (yr) 100.1389790741915
# 100000.0
# initial time (yr) 0.10018282181357008 final time (yr) 100.14064362714014
# 1000000.0
# initial time (yr) 0.1002219435637286 final time (yr) 100.06823398858592
# 5000000.0
# initial time (yr) 0.10028450221940394 final time (yr) 100.09526949904883

# %%
rhoISM_vals = [1000,1e4,1e5,1e6,5e6] #in secinyear

for rhoISM in rhoISM_vals:
    print(rhoISM)
    shell_data = np.loadtxt('../shell_propagation/shell_evolution_rhoISM_%ge-24_cgs.txt' % rhoISM)
    time = shell_data[:,0] #s
    rsh = shell_data[:,1] #cm
    vsh = shell_data[:,2] #cm/s
    # deltav_1 = shell_data[:,3] #cm/s
    deltav_2 = shell_data[:,3] #cm/s
    rho_const = shell_data[:,4] #g/cm^3
    rhofl_2 = shell_data[:,5] #g/cm^3
    int_rhofl_1_sq_dr = shell_data[:,6] #g^2/cm^5 
    print('initial time (yr)',time[0]/secinyear, 'final time (yr)', time[-1]/secinyear)
    plt.figure()
    plt.plot(time,rho_const,color='crimson',label=r'$\rho_{\rm ISM}$')
    plt.plot(time,rhofl_2,color='dodgerblue',label=r'$\rho_{2}$')
    plt.xlabel('Time (s)')
    plt.ylabel('Density (g/cm$^3$)')
    plt.xlim(1e5,1e10)
    plt.ylim(1e-28,2e-15)
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    plt.grid(linestyle=':')
    plt.title('rho_ISM = %ge-24 g/cm3' % rhoISM)
# Out:
# 1000
# initial time (yr) 0.10016544705136335 final time (yr) 100.14579264426125
# 10000.0
# initial time (yr) 0.10016968611287254 final time (yr) 100.1389790741915
# 100000.0
# initial time (yr) 0.10018282181357008 final time (yr) 100.14064362714014
# 1000000.0
# initial time (yr) 0.1002219435637286 final time (yr) 100.06823398858592
# 5000000.0
# initial time (yr) 0.10028450221940394 final time (yr) 100.09526949904883

# %%
rhoISM_vals = [1000,1e4,1e5,1e6,5e6] #in secinyear

for rhoISM in rhoISM_vals:
    print(rhoISM)
    shell_data = np.loadtxt('../shell_propagation/shell_evolution_rhoISM_%ge-24_cgs.txt' % rhoISM)
    time = shell_data[:,0] #s
    rsh = shell_data[:,1] #cm
    vsh = shell_data[:,2] #cm/s
    # deltav_1 = shell_data[:,3] #cm/s
    deltav_2 = shell_data[:,3] #cm/s
    rho_const = shell_data[:,4] #g/cm^3
    rhofl_2 = shell_data[:,5] #g/cm^3
    int_rhofl_1_sq_dr = shell_data[:,6] #g^2/cm^5 
    print('initial time (yr)',time[0]/secinyear, 'final time (yr)', time[-1]/secinyear)
    plt.figure()
    plt.plot(rsh,rho_const,color='crimson',label=r'$\rho_{\rm ISM}$')
    plt.plot(rsh,rhofl_2,color='dodgerblue',label=r'$\rho_{2}$')
    plt.plot(rsh, rhoISM*1e-24*(rsh/rsh[0])**(-2.5),color='black',ls='--',label=r'$\rho_{\rm ISM} \propto r^{-2.5}$')
    plt.axhline(1e3*1e-24,color='black',ls=':',label=r'$\rho_{\rm ISM}=1e3 \times 10^{-24}$ g/cm$^3$')
    plt.axhline(1e4*1e-24,color='brown',ls=':',label=r'$\rho_{\rm ISM}=1e4 \times 10^{-24}$ g/cm$^3$')
    plt.xlabel('Distance (cm)')
    plt.ylabel('Density (g/cm$^3$)')
    # plt.xlim(1e5,1e10)
    plt.ylim(1e-28,2e-15)
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    plt.grid(linestyle=':')
    plt.title('rho_ISM = %ge-24 g/cm3' % rhoISM)
# Out:
# 1000
# initial time (yr) 0.10016544705136335 final time (yr) 100.14579264426125
# 10000.0
# initial time (yr) 0.10016968611287254 final time (yr) 100.1389790741915
# 100000.0
# initial time (yr) 0.10018282181357008 final time (yr) 100.14064362714014
# 1000000.0
# initial time (yr) 0.1002219435637286 final time (yr) 100.06823398858592
# 5000000.0
# initial time (yr) 0.10028450221940394 final time (yr) 100.09526949904883

# %%
rhoISM_vals = [1000,1e4,1e5,1e6,5e6] #in secinyear
colors=['tomato','darkolivegreen','orange','cornflowerblue','purple']
for i,rhoISM in enumerate(rhoISM_vals):
    print(rhoISM)
    shell_data = np.loadtxt('../shell_propagation/shell_evolution_rhoISM_%ge-24_cgs.txt' % rhoISM)
    time = shell_data[:,0] #s
    rsh = shell_data[:,1] #cm
    vsh = shell_data[:,2] #cm/s
    # deltav_1 = shell_data[:,3] #cm/s
    deltav_2 = shell_data[:,3] #cm/s
    rho_const = shell_data[:,4] #g/cm^3
    rhofl_2 = shell_data[:,5] #g/cm^3
    int_rhofl_1_sq_dr = shell_data[:,6] #g^2/cm^5 
    print('initial time (yr)',time[0]/secinyear, 'final time (yr)', time[-1]/secinyear)
    # plt.figure()
    plt.plot(time,int_rhofl_1_sq_dr,color=colors[i],label='rho_ISM = %ge-24 g/cm3' % rhoISM)

    plt.xlabel('Time (s)')
    plt.ylabel('Density integral (g$^2$/cm$^5$)')
    plt.xlim(1e5,1e10)
    # plt.ylim(1e-,2e-17)
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    plt.grid(linestyle=':')
    # plt.title('delta t = %g yr' % deltat)
# Out:
# 1000
# initial time (yr) 0.10016544705136335 final time (yr) 100.14579264426125
# 10000.0
# initial time (yr) 0.10016968611287254 final time (yr) 100.1389790741915
# 100000.0
# initial time (yr) 0.10018282181357008 final time (yr) 100.14064362714014
# 1000000.0
# initial time (yr) 0.1002219435637286 final time (yr) 100.06823398858592
# 5000000.0
# initial time (yr) 0.10028450221940394 final time (yr) 100.09526949904883

# %%
rhoISM_vals = [1000,1e4,1e5,1e6,5e6] #in secinyear
colors=['tomato','darkolivegreen','orange','cornflowerblue','purple']
for i,rhoISM in enumerate(rhoISM_vals):
    print(rhoISM)
    shell_data = np.loadtxt('../shell_propagation/shell_evolution_rhoISM_%ge-24_cgs.txt' % rhoISM)
    time = shell_data[:,0] #s
    rsh = shell_data[:,1] #cm
    vsh = shell_data[:,2] #cm/s
    # deltav_1 = shell_data[:,3] #cm/s
    deltav_2 = shell_data[:,3] #cm/s
    rho_const = shell_data[:,4] #g/cm^3
    rhofl_2 = shell_data[:,5] #g/cm^3
    int_rhofl_1_sq_dr = shell_data[:,6] #g^2/cm^5 
    print('initial time (yr)',time[0]/secinyear, 'final time (yr)', time[-1]/secinyear)
    # plt.figure()
    plt.plot(time,rsh,color=colors[i],label='rho_ISM = %ge-24 g/cm3' % rhoISM)
    c = 2.9989e10
    plt.plot(time,0.1 * c * time,color=colors[i],label='v_max t', ls=':')

    plt.xlabel('Time (s)')
    plt.ylabel('Shock radius (cm)')
    plt.xlim(1e5,1e10)
    # plt.ylim(1e-,2e-17)
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    plt.grid(linestyle=':')
    # plt.title('delta t = %g yr' % deltat)
# Out:
# 1000
# initial time (yr) 0.10016544705136335 final time (yr) 100.14579264426125
# 10000.0
# initial time (yr) 0.10016968611287254 final time (yr) 100.1389790741915
# 100000.0
# initial time (yr) 0.10018282181357008 final time (yr) 100.14064362714014
# 1000000.0
# initial time (yr) 0.1002219435637286 final time (yr) 100.06823398858592
# 5000000.0
# initial time (yr) 0.10028450221940394 final time (yr) 100.09526949904883

# %% [markdown]
# ## check loading shock_data.npz

# %%
# shock_data = np.load('./evolve_spectrum_epsB_1e-1/shell_evolution_deltat_0.3yr/shock_data.npz')
shock_data = np.load('./evolve_spectrum_epsB_1e-1/shell_evolution_rhoISM_5e+06e-24_cgs/shock_data.npz')

# %%
plt.plot(shock_data['times'], shock_data['vsh_of_t'],color='black',ls=':',label=r'$v_{\rm sh}$')
# plt.plot(shock_data['times'], shock_data['vsh_of_t']-shock_data['deltav1_of_t'],color='crimson',label=r'$v_{1}$')
plt.plot(shock_data['times'], shock_data['deltav2_of_t']+shock_data['vsh_of_t'],color='dodgerblue',label=r'$v_{2}$')
plt.xlabel('Time (s)')
plt.ylabel('Shell Velocity (cm/s)')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.xlim(1e5,1e10)
plt.grid(which='both',linestyle=':')

# %%
plt.plot(shock_data['times'], shock_data['rho_const'],color='crimson',label=r'$\rho_{\rm ISM}$')
plt.plot(shock_data['times'], shock_data['rho2_of_t'],color='dodgerblue',label=r'$\rho_{2}$')

plt.xlabel('Time (s)')
plt.ylabel('Density (g/cm$^3$)')

plt.xlim(1e5,1e10)
plt.ylim(1e-28,4e-17)
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.grid(linestyle=':')

# %%
plt.plot(shock_data['rsh_of_t'], shock_data['rho_const'],color='crimson',label=r'$\rho_{\rm ISM}$')
plt.plot(shock_data['rsh_of_t'], shock_data['rho2_of_t'],color='dodgerblue',label=r'$\rho_{2}$')
plt.plot(shock_data['rsh_of_t'], 5e11/(shock_data['rsh_of_t']**2),color='black',label=r'5e11 g cm$^{-1}$/$r^2$')

plt.xlabel('Radius (cm)')
plt.ylabel('Density (g/cm$^3$)')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.ylim(1e-28,2e-17)
plt.grid(linestyle=':')

# %%
p=3

def B(eps_B,rho,vel): #inputs in CGS
    return np.sqrt(8*np.pi*eps_B*rho*vel**2) #in Gauss
#assuming gamma_max -> infty, normalization of dn/dgamma = n0 * gamma^-p is:
def n0(eps_E,gamma_min,rho,vel,p=p): #this is number density for the energy distribution dn/dgamma
    return eps_E*((p-2)*gamma_min**(p-2))*rho*vel**2/(m_e.cgs.value*c.cgs.value**2)

# %%
# plt.plot(shock_data['times'],B(1e-2,shock_data['rho_const'],shock_data['deltav1_of_t']),color='crimson',label=r'$\rho_{1}$')
plt.plot(shock_data['times'],B(1e-2,shock_data['rho2_of_t'],shock_data['deltav2_of_t']),color='dodgerblue',label=r'$\rho_{2}$')

plt.xlabel('Time (s)')
plt.ylabel('B Field (G)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
shock_data['times']/secinyear
# Out:
# array([  0.10032561,   0.10072378,   0.10103485, ...,  99.88323716,
#        100.03358275, 100.18415663])

# %% [markdown]
# # check loading spectrum data

# %% [markdown]
# ## for rho_ISM = 1000e-24 g/cm^3

# %%
data_dir='./evolve_spectrum_epsB_1e-1/shell_evolution_rhoISM_1000e-24_cgs/'
# flare1_dir = data_dir+'/flare1/'
flare2_dir = data_dir+'/flare2/'

# %%
from astropy.constants import sigma_T,m_e,c
from scipy.interpolate import interp1d
# python spectrum_evolution.py 'evolve_spectrum/E_1.00E+51_Mej_1.00E+00_rhoprof_2.898M_Porb10/' \n
#'evolve_spectrum/evolve_spectrum_implicit/' --max_step=20000 --print_int=5000 --dt_sc=1e-3 --tf=1e6
km_s = 1e5 #* cm/s
G = 6.67430e-8
Msun = 1.989e33
Lsun = 3.828e33
Rsun = 6.96e10

secinyear = 3.154e7
secinday = 86400

eps_B=0.1
eps_E=0.1
p=3

def B(eps_B,rho,vel): #inputs in CGS
    return np.sqrt(8*np.pi*eps_B*rho*vel**2) #in Gauss
#assuming gamma_max -> infty, normalization of dn/dgamma = n0 * gamma^-p is:
def n0(eps_E,gamma_min,rho,vel): #this is number density for the energy distribution dn/dgamma
    return eps_E*gamma_min*rho*vel**2/(m_e.cgs.value*c.cgs.value**2)
#usually assume gamma_min=1
#adopt p=3 also
dndgamma_func = lambda gamma,n0_const,p: n0_const*gamma**(-p)

dict_colors=['crimson','dodgerblue']
dict_linestyles=['-','-']
# datadir_list = []
dNdgamma_dir_list = []
# for key in dict_4p08M_paths.keys():

# dNdgamma_dir_list.append(flare1_dir)
# datadir_list.append('./evolve_spectrum_epsB_1e-2/')
dNdgamma_dir_list.append(flare2_dir)

shock_data = np.load(data_dir + 'shock_data.npz')
times_orig = shock_data['times']
vsh_orig = shock_data['vsh_of_t']
rsh_of_t = shock_data['rsh_of_t']
rho_const = shock_data['rho_const']
rho2_of_t = shock_data['rho2_of_t']
# deltav1_of_t = shock_data['deltav1_of_t']
deltav2_of_t = shock_data['deltav2_of_t']

fig, ax = plt.subplots(3,1,figsize=(6,8),sharex=True)
for dNdgamma_dir in dNdgamma_dir_list:
    # if flare==0:
    #     rho_of_t = rho_const
    #     vsh_of_t = deltav1_of_t
    flare = 1
    rho_of_t = rho2_of_t
    vsh_of_t = vsh_orig
    print('flare',flare+1)
    # if key != 'fomega0p3':
    #     continue
    B_of_t = B(eps_B=eps_B,rho=rho_of_t,vel=vsh_of_t)
    times = times_orig
    ind_start=0
    print(ind_start)
    vsh_of_t = vsh_of_t[ind_start:]
    rsh_of_t = rsh_of_t[ind_start:]
    rho_of_t = rho_of_t[ind_start:]

    n0_of_t = n0(eps_E=eps_E,gamma_min=1,rho=rho_of_t,vel=vsh_of_t)
    # B_of_t = B(eps_B=1e-2,rho=rho_of_t,vel=vsh_of_t)

    #nondimensionalize to initial values of vsh, rsh, and initial dynamical time t_dyn ~ rsh/vsh
    adjust_const = 1 #1e-12
    vsh_t0 = vsh_orig[0]
    rsh_t0 = rsh_of_t[0]
    tdyn_t0 = rsh_t0/vsh_t0
    #also scale N by initial value N_t0 = n0_t0 * rsh_t0**3
    n0_t0 = n0_of_t[0]
    N_t0 = n0_t0 * rsh_t0**3

    vsh_tot_func_ND = interp1d(times/tdyn_t0,vsh_orig/vsh_t0,kind='linear')
    vsh_func_ND = interp1d(times/tdyn_t0,vsh_of_t/vsh_t0,kind='linear')
    rsh_func_ND = interp1d(times/tdyn_t0,rsh_of_t/rsh_t0,kind='linear')
    n0_func_ND = interp1d(times/tdyn_t0,n0_of_t/n0_t0,kind='linear')

    B_func = interp1d(times/tdyn_t0,B_of_t,kind='linear')
    coeff_rad_ND = lambda t: -((sigma_T.cgs.value * B_func(t)**2)/(6 * np.pi * m_e.cgs.value * c.cgs.value))*tdyn_t0

    print("initial dynamical time, shock radius, shock velocity, normalization constant", 
        f'{tdyn_t0:1.3E} s, {rsh_t0:1.3E} cm,{vsh_t0:1.3E} cm/s,{n0_t0:1.3E} cm^-3')
    print('minimum time', times[0]/tdyn_t0,'initial B field',B_func(times[0]/tdyn_t0),B_of_t[0],'max time',times[-1]/tdyn_t0)

    #time dependent coefficients for heating and cooling terms
    c1 = lambda t: -vsh_tot_func_ND(t)/rsh_func_ND(t)/adjust_const
    c2 = lambda t: coeff_rad_ND(t)/adjust_const
    c3 = lambda t: 4 * np.pi * rsh_func_ND(t)**2 * vsh_func_ND(t) * n0_func_ND(t)/adjust_const

    print('c1',c1(times[0]/tdyn_t0),'c2',c2(times[0]/tdyn_t0), 'c3',c3(times[0]/tdyn_t0) )

    # delta_gamma = 100
    delta_gamma = 1e-3 # not using even spacing
    gamma_max = 1e8 #actually calculate this
    gamma_min = 1
    N_g = 256
    d_ln_gamma = (np.log(gamma_max) - np.log(gamma_min))/N_g
    # gamma_e_vals = np.arange(gamma_min,gamma_max,delta_gamma)
    gamma_e_vals = np.zeros(N_g)
    gamma_e_vals[0] = gamma_min
    for i in np.arange(1,N_g):
        gamma_e_vals[i] = gamma_e_vals[i-1] + (np.exp(d_ln_gamma)-1)*gamma_e_vals[i-1]
    delta_gamma_e = gamma_e_vals*(np.exp(d_ln_gamma)-1)

    dt_scale_sim = 1e-3

    dts = np.load(dNdgamma_dir+'dts.npy')
    tvals=np.load(dNdgamma_dir+'times.npy')
    yvals=np.load(dNdgamma_dir+'yvals.npz')['arr_0'].reshape((len(tvals),len(gamma_e_vals)))
    #convert yvals to the right units
    dNdgamma_vals = yvals * n0_t0 * rsh_t0**3
    print('normalization',n0_t0 * rsh_t0**3)
    tdyn_of_t_sim = dts/dt_scale_sim

    tvals_sec = tvals*tdyn_t0
    print('minimum time', tvals_sec[0]/secinyear,'maximum time', tvals_sec[-1]/secinyear, 'yr')
    print('max time times',times[-1]/secinyear,'max time tvals',tvals[-1]*tdyn_t0/secinyear)
    # print(dNdgamma_vals[:,0].shape,tvals.shape)
    ax[0].plot(tvals_sec,dNdgamma_vals[:,0],color=dict_colors[flare],ls=dict_linestyles[flare],label='flare'+str(flare+1))

    ax[1].plot(times,rho_of_t,color=dict_colors[flare],ls=dict_linestyles[flare])
    ax[2].plot(times,B_of_t,color=dict_colors[flare],ls=dict_linestyles[flare])
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[2].set_yscale('log')
ax[2].set_xscale('log')
# ax[2].set_xlim(1e-5,)
ax[0].set_ylabel(r'$\frac{dN}{d\gamma}$')
ax[1].set_ylabel(r'$\rho$')
ax[2].set_ylabel(r'B')
ax[2].set_xlabel('Time [s]')
ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[0].set_ylim(1e44,1e56)
ax[1].set_ylim(1e-23,1e-14)
ax[2].set_ylim(1e-6,1e2)
ax[2].set_xlim(1e-2*secinyear,200*secinyear)
ax[0].legend()
plt.savefig(data_dir+'dNdgamma_rho_B.png',bbox_inches='tight',transparent=False,facecolor='white')
# Out:
# flare 2
# 0
# initial dynamical time, shock radius, shock velocity, normalization constant 3.236E+06 s, 9.474E+15 cm,2.927E+09 cm/s,1.298E+03 cm^-3
# minimum time 0.9761533710271558 initial B field 0.16341857244851124 0.16341857244851124 max time 975.9618307673852
# c1 -1.0 c2 -0.00011169552056329904 c3 0.30723955066127306
# normalization 1.1036509167131577e+51
# minimum time 0.1011032126506439 maximum time 99.63724484140698 yr
# max time times 100.14579264426125 max time tvals 99.63724484140698

# %% [markdown]
# # check loading emission

# %%
def t_cool_syn(nu, B):
    from astropy.constants import m_e, sigma_T, e, c
    # print(e.gauss.value, sigma_T.cgs.value, m_e.cgs.value)
    # gamma_lorentz = np.sqrt(1-(vel/c.cgs.value)**2)**(-1)
    return (3/sigma_T.cgs.value) * np.sqrt(2*np.pi*c.cgs.value*m_e.cgs.value*e.gauss.value/(B**3)) * nu**(-0.5)

# %% [markdown]
# ## for rho_ISM = 1000e-24 g/cm^3

# %%
data_dir='./evolve_spectrum_epsB_1e-1/shell_evolution_rhoISM_1000e-24_cgs/'
# flare1_dir = data_dir+'/flare1/'
flare2_dir = data_dir+'/flare2/'

eps_B=0.1
eps_E=0.1

# %%
from astropy.constants import m_e, sigma_T, e, c
eps_B=0.1
eps_E=0.1

def B(eps_B,rho,vel): #inputs in CGS
    return np.sqrt(8*np.pi*eps_B*rho*vel**2) #in Gauss
#assuming gamma_max -> infty, normalization of dn/dgamma = n0 * gamma^-p is:
def n0(eps_E,gamma_min,rho,vel): #this is number density for the energy distribution dn/dgamma
    return eps_E*gamma_min*rho*vel**2/(m_e.cgs.value*c.cgs.value**2)
#usually assume gamma_min=1
#adopt p=3 also
dndgamma_func = lambda gamma,n0_const,p: n0_const*gamma**(-p)

dict_colors=['crimson','dodgerblue']
dict_linestyles=['-','-']
# datadir_list = []
dNdgamma_dir_list = []
# for key in dict_4p08M_paths.keys():
# data_dir='./evolve_spectrum_epsB_1e-2/shell_evolution_deltat_1yr/'
# dNdgamma_dir_list.append(flare1_dir)
# datadir_list.append('./evolve_spectrum_epsB_1e-2/')
dNdgamma_dir_list.append(flare2_dir)

shock_data = np.load(data_dir + 'shock_data.npz')
times = shock_data['times']
vsh_orig = shock_data['vsh_of_t']
rsh_of_t = shock_data['rsh_of_t']
rho_const = shock_data['rho_const']
rho2_of_t = shock_data['rho2_of_t']
# deltav1_of_t = shock_data['deltav1_of_t']
deltav2_of_t = shock_data['deltav2_of_t']

colors = ['crimson','dodgerblue']
# fig, ax = plt.subplots(3,1,figsize=(6,8),sharex=True)
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
for dNdgamma_dir in dNdgamma_dir_list:
    # if flare==0:
    #     rho_of_t = rho_const
    #     vsh_of_t = deltav1_of_t
    # elif flare==1:
    #     rho_of_t = rho2_of_t
    #     vsh_of_t = vsh_orig
    flare = 1
    rho_of_t = rho2_of_t
    vsh_of_t = vsh_orig
    print('flare',flare+1)
    print('flare',flare+1)
    # if key != 'fomega0p3':
    #     continue
    B_of_t = B(eps_B=eps_B,rho=rho_of_t,vel=vsh_of_t)
    gamma_cool = (100*(B_of_t/0.5)**(-2) * (rsh_of_t/vsh_orig/secinyear)**(-1))
    nu_cool = gamma_cool**2 * (1/2/np.pi)*e.gauss.value*B_of_t/(m_e.cgs.value*c.cgs.value)
    ax1.plot(times/secinyear,nu_cool/1e9)
    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_ylim(1e-2,1e14)
    ax1.set_ylabel('Frequency (GHz)')
    ax1.set_xlabel('Time (yr)')
    # plt.plot(times,B_of_t)

        # label1 = 'synchrotron cooling time'
    label2 = 'adiabatic cooling time'
    label1 = '3 GHz t_cool,syn'
    label3 = '10 GHz t_cool,syn'
    label4 = '15 GHz t_cool,syn'
    # plt.figure()
    ax2.plot(times/secinyear,t_cool_syn(3e9,B_of_t)/secinyear,label=label1,ls='--',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(10e9,B_of_t)/secinyear,label=label3,ls=':',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(15e9,B_of_t)/secinyear,label=label4,ls='-.',color=colors[flare])
    ax2.plot(times/secinyear, (rsh_of_t/vsh_orig)/secinyear,label=label2,color=colors[flare],zorder=1-flare)
ax2.legend()
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_xlim(1e-2,10)
# ax2.set_ylim(1e-3,100)
ax2.set_xlabel('Time (yr)')
ax2.set_ylabel('Cooling time (yr)')
# Out:
# flare 2
# flare 2
# Text(0, 0.5, 'Cooling time (yr)')

# %%
flare2_dict = {}

flare2_dict['peak_data'] = np.load(flare2_dir+'peak_data.npz')

flare2_dict['Lnu_3GHz'] = np.load(flare2_dir+'Lnu_3.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_10GHz'] = np.load(flare2_dir+'Lnu_10.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_15GHz'] = np.load(flare2_dir+'Lnu_15.00GHz_sparse_Te_1.0E+04.npz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e15,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_3GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ff_atfreq'],color='dodgerblue',label='flare2',ls=':')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ff}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
# plt.ylim(1e-10,1e6)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e15,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_10GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
# plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e15,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_15GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,1e2)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =1000 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_Lnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr']*365.25,3e9*flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr']*365.25,10e9*flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr']*365.25,15e9*flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [days]')
plt.ylabel(r'$\nu L_{\nu}$ [erg/s]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e30,1e40)
plt.xlim(1,1e5)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =1000 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_nuLnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %% [markdown]
# ## for rho_ISM = 10000e-24 g/cm^3

# %%
data_dir='./evolve_spectrum_epsB_1e-1/shell_evolution_rhoISM_10000e-24_cgs/'
# flare1_dir = data_dir+'/flare1/'
flare2_dir = data_dir+'/flare2/'

eps_B=0.1
eps_E=0.1

# %%
from astropy.constants import m_e, sigma_T, e, c
eps_B=0.1
eps_E=0.1

def B(eps_B,rho,vel): #inputs in CGS
    return np.sqrt(8*np.pi*eps_B*rho*vel**2) #in Gauss
#assuming gamma_max -> infty, normalization of dn/dgamma = n0 * gamma^-p is:
def n0(eps_E,gamma_min,rho,vel): #this is number density for the energy distribution dn/dgamma
    return eps_E*gamma_min*rho*vel**2/(m_e.cgs.value*c.cgs.value**2)
#usually assume gamma_min=1
#adopt p=3 also
dndgamma_func = lambda gamma,n0_const,p: n0_const*gamma**(-p)

dict_colors=['crimson','dodgerblue']
dict_linestyles=['-','-']
# datadir_list = []
dNdgamma_dir_list = []
# for key in dict_4p08M_paths.keys():
# data_dir='./evolve_spectrum_epsB_1e-2/shell_evolution_deltat_1yr/'
# dNdgamma_dir_list.append(flare1_dir)
# datadir_list.append('./evolve_spectrum_epsB_1e-2/')
dNdgamma_dir_list.append(flare2_dir)

shock_data = np.load(data_dir + 'shock_data.npz')
times = shock_data['times']
vsh_orig = shock_data['vsh_of_t']
rsh_of_t = shock_data['rsh_of_t']
rho_const = shock_data['rho_const']
rho2_of_t = shock_data['rho2_of_t']
# deltav1_of_t = shock_data['deltav1_of_t']
deltav2_of_t = shock_data['deltav2_of_t']

colors = ['crimson','dodgerblue']
# fig, ax = plt.subplots(3,1,figsize=(6,8),sharex=True)
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
for dNdgamma_dir in dNdgamma_dir_list:
    # if flare==0:
    #     rho_of_t = rho_const
    #     vsh_of_t = deltav1_of_t
    # elif flare==1:
    #     rho_of_t = rho2_of_t
    #     vsh_of_t = vsh_orig
    flare = 1
    rho_of_t = rho2_of_t
    vsh_of_t = vsh_orig
    print('flare',flare+1)
    print('flare',flare+1)
    # if key != 'fomega0p3':
    #     continue
    B_of_t = B(eps_B=eps_B,rho=rho_of_t,vel=vsh_of_t)
    gamma_cool = (100*(B_of_t/0.5)**(-2) * (rsh_of_t/vsh_orig/secinyear)**(-1))
    nu_cool = gamma_cool**2 * (1/2/np.pi)*e.gauss.value*B_of_t/(m_e.cgs.value*c.cgs.value)
    ax1.plot(times/secinyear,nu_cool/1e9)
    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_ylim(1e-2,1e14)
    ax1.set_ylabel('Frequency (GHz)')
    ax1.set_xlabel('Time (yr)')
    # plt.plot(times,B_of_t)

        # label1 = 'synchrotron cooling time'
    label2 = 'adiabatic cooling time'
    label1 = '3 GHz t_cool,syn'
    label3 = '10 GHz t_cool,syn'
    label4 = '15 GHz t_cool,syn'
    # plt.figure()
    ax2.plot(times/secinyear,t_cool_syn(3e9,B_of_t)/secinyear,label=label1,ls='--',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(10e9,B_of_t)/secinyear,label=label3,ls=':',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(15e9,B_of_t)/secinyear,label=label4,ls='-.',color=colors[flare])
    ax2.plot(times/secinyear, (rsh_of_t/vsh_orig)/secinyear,label=label2,color=colors[flare],zorder=1-flare)
ax2.legend()
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_xlim(1e-2,10)
# ax2.set_ylim(1e-3,100)
ax2.set_xlabel('Time (yr)')
ax2.set_ylabel('Cooling time (yr)')
# Out:
# flare 2
# flare 2
# Text(0, 0.5, 'Cooling time (yr)')

# %%
flare2_dict = {}

flare2_dict['peak_data'] = np.load(flare2_dir+'peak_data.npz')

flare2_dict['Lnu_3GHz'] = np.load(flare2_dir+'Lnu_3.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_10GHz'] = np.load(flare2_dir+'Lnu_10.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_15GHz'] = np.load(flare2_dir+'Lnu_15.00GHz_sparse_Te_1.0E+04.npz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_3GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ff_atfreq'],color='dodgerblue',label='flare2',ls=':')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ff}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e6)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_10GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_15GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,1e2)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =10000 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_Lnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr']*365.25,3e9*flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr']*365.25,10e9*flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr']*365.25,15e9*flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [days]')
plt.ylabel(r'$\nu L_{\nu}$ [erg/s]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e30,1e40)
plt.xlim(1,1e5)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =10000 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_nuLnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %% [markdown]
# ## for rho_ISM = 10000e-24 g/cm^3

# %%
data_dir='./evolve_spectrum_epsB_1e-1/shell_evolution_rhoISM_100000e-24_cgs/'
# flare1_dir = data_dir+'/flare1/'
flare2_dir = data_dir+'/flare2/'

eps_B=0.1
eps_E=0.1

# %%
from astropy.constants import m_e, sigma_T, e, c
eps_B=0.1
eps_E=0.1

def B(eps_B,rho,vel): #inputs in CGS
    return np.sqrt(8*np.pi*eps_B*rho*vel**2) #in Gauss
#assuming gamma_max -> infty, normalization of dn/dgamma = n0 * gamma^-p is:
def n0(eps_E,gamma_min,rho,vel): #this is number density for the energy distribution dn/dgamma
    return eps_E*gamma_min*rho*vel**2/(m_e.cgs.value*c.cgs.value**2)
#usually assume gamma_min=1
#adopt p=3 also
dndgamma_func = lambda gamma,n0_const,p: n0_const*gamma**(-p)

dict_colors=['crimson','dodgerblue']
dict_linestyles=['-','-']
# datadir_list = []
dNdgamma_dir_list = []
# for key in dict_4p08M_paths.keys():
# data_dir='./evolve_spectrum_epsB_1e-2/shell_evolution_deltat_1yr/'
# dNdgamma_dir_list.append(flare1_dir)
# datadir_list.append('./evolve_spectrum_epsB_1e-2/')
dNdgamma_dir_list.append(flare2_dir)

shock_data = np.load(data_dir + 'shock_data.npz')
times = shock_data['times']
vsh_orig = shock_data['vsh_of_t']
rsh_of_t = shock_data['rsh_of_t']
rho_const = shock_data['rho_const']
rho2_of_t = shock_data['rho2_of_t']
# deltav1_of_t = shock_data['deltav1_of_t']
deltav2_of_t = shock_data['deltav2_of_t']

colors = ['crimson','dodgerblue']
# fig, ax = plt.subplots(3,1,figsize=(6,8),sharex=True)
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
for dNdgamma_dir in dNdgamma_dir_list:
    # if flare==0:
    #     rho_of_t = rho_const
    #     vsh_of_t = deltav1_of_t
    # elif flare==1:
    #     rho_of_t = rho2_of_t
    #     vsh_of_t = vsh_orig
    flare = 1
    rho_of_t = rho2_of_t
    vsh_of_t = vsh_orig
    print('flare',flare+1)
    print('flare',flare+1)
    # if key != 'fomega0p3':
    #     continue
    B_of_t = B(eps_B=eps_B,rho=rho_of_t,vel=vsh_of_t)
    gamma_cool = (100*(B_of_t/0.5)**(-2) * (rsh_of_t/vsh_orig/secinyear)**(-1))
    nu_cool = gamma_cool**2 * (1/2/np.pi)*e.gauss.value*B_of_t/(m_e.cgs.value*c.cgs.value)
    ax1.plot(times/secinyear,nu_cool/1e9)
    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_ylim(1e-2,1e14)
    ax1.set_ylabel('Frequency (GHz)')
    ax1.set_xlabel('Time (yr)')
    # plt.plot(times,B_of_t)

        # label1 = 'synchrotron cooling time'
    label2 = 'adiabatic cooling time'
    label1 = '3 GHz t_cool,syn'
    label3 = '10 GHz t_cool,syn'
    label4 = '15 GHz t_cool,syn'
    # plt.figure()
    ax2.plot(times/secinyear,t_cool_syn(3e9,B_of_t)/secinyear,label=label1,ls='--',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(10e9,B_of_t)/secinyear,label=label3,ls=':',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(15e9,B_of_t)/secinyear,label=label4,ls='-.',color=colors[flare])
    ax2.plot(times/secinyear, (rsh_of_t/vsh_orig)/secinyear,label=label2,color=colors[flare],zorder=1-flare)
ax2.legend()
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_xlim(1e-2,10)
# ax2.set_ylim(1e-3,100)
ax2.set_xlabel('Time (yr)')
ax2.set_ylabel('Cooling time (yr)')
# Out:
# flare 2
# flare 2
# Text(0, 0.5, 'Cooling time (yr)')

# %%
flare2_dict = {}

flare2_dict['peak_data'] = np.load(flare2_dir+'peak_data.npz')

flare2_dict['Lnu_3GHz'] = np.load(flare2_dir+'Lnu_3.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_10GHz'] = np.load(flare2_dir+'Lnu_10.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_15GHz'] = np.load(flare2_dir+'Lnu_15.00GHz_sparse_Te_1.0E+04.npz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_3GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ff_atfreq'],color='dodgerblue',label='flare2',ls=':')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ff}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e6)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_10GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_15GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,1e2)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =100000 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_Lnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr']*365.25,3e9*flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr']*365.25,10e9*flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr']*365.25,15e9*flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [days]')
plt.ylabel(r'$\nu L_{\nu}$ [erg/s]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e30,1e40)
plt.xlim(1,1e5)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =100000 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_nuLnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %% [markdown]
# ## for rho_ISM = 1e6e-24 g/cm^3

# %%
data_dir='./evolve_spectrum_epsB_1e-1/shell_evolution_rhoISM_1e+06e-24_cgs/'
# flare1_dir = data_dir+'/flare1/'
flare2_dir = data_dir+'/flare2/'

eps_B=0.1
eps_E=0.1

# %%
from astropy.constants import m_e, sigma_T, e, c
eps_B=0.1
eps_E=0.1

def B(eps_B,rho,vel): #inputs in CGS
    return np.sqrt(8*np.pi*eps_B*rho*vel**2) #in Gauss
#assuming gamma_max -> infty, normalization of dn/dgamma = n0 * gamma^-p is:
def n0(eps_E,gamma_min,rho,vel): #this is number density for the energy distribution dn/dgamma
    return eps_E*gamma_min*rho*vel**2/(m_e.cgs.value*c.cgs.value**2)
#usually assume gamma_min=1
#adopt p=3 also
dndgamma_func = lambda gamma,n0_const,p: n0_const*gamma**(-p)

dict_colors=['crimson','dodgerblue']
dict_linestyles=['-','-']
# datadir_list = []
dNdgamma_dir_list = []
# for key in dict_4p08M_paths.keys():
# data_dir='./evolve_spectrum_epsB_1e-2/shell_evolution_deltat_1yr/'
# dNdgamma_dir_list.append(flare1_dir)
# datadir_list.append('./evolve_spectrum_epsB_1e-2/')
dNdgamma_dir_list.append(flare2_dir)

shock_data = np.load(data_dir + 'shock_data.npz')
times = shock_data['times']
vsh_orig = shock_data['vsh_of_t']
rsh_of_t = shock_data['rsh_of_t']
rho_const = shock_data['rho_const']
rho2_of_t = shock_data['rho2_of_t']
# deltav1_of_t = shock_data['deltav1_of_t']
deltav2_of_t = shock_data['deltav2_of_t']

colors = ['crimson','dodgerblue']
# fig, ax = plt.subplots(3,1,figsize=(6,8),sharex=True)
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
for dNdgamma_dir in dNdgamma_dir_list:
    # if flare==0:
    #     rho_of_t = rho_const
    #     vsh_of_t = deltav1_of_t
    # elif flare==1:
    #     rho_of_t = rho2_of_t
    #     vsh_of_t = vsh_orig
    flare = 1
    rho_of_t = rho2_of_t
    vsh_of_t = vsh_orig
    print('flare',flare+1)
    print('flare',flare+1)
    # if key != 'fomega0p3':
    #     continue
    B_of_t = B(eps_B=eps_B,rho=rho_of_t,vel=vsh_of_t)
    gamma_cool = (100*(B_of_t/0.5)**(-2) * (rsh_of_t/vsh_orig/secinyear)**(-1))
    nu_cool = gamma_cool**2 * (1/2/np.pi)*e.gauss.value*B_of_t/(m_e.cgs.value*c.cgs.value)
    ax1.plot(times/secinyear,nu_cool/1e9)
    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_ylim(1e-2,1e14)
    ax1.set_ylabel('Frequency (GHz)')
    ax1.set_xlabel('Time (yr)')
    # plt.plot(times,B_of_t)

        # label1 = 'synchrotron cooling time'
    label2 = 'adiabatic cooling time'
    label1 = '3 GHz t_cool,syn'
    label3 = '10 GHz t_cool,syn'
    label4 = '15 GHz t_cool,syn'
    # plt.figure()
    ax2.plot(times/secinyear,t_cool_syn(3e9,B_of_t)/secinyear,label=label1,ls='--',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(10e9,B_of_t)/secinyear,label=label3,ls=':',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(15e9,B_of_t)/secinyear,label=label4,ls='-.',color=colors[flare])
    ax2.plot(times/secinyear, (rsh_of_t/vsh_orig)/secinyear,label=label2,color=colors[flare],zorder=1-flare)
ax2.legend()
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_xlim(1e-2,10)
# ax2.set_ylim(1e-3,100)
ax2.set_xlabel('Time (yr)')
ax2.set_ylabel('Cooling time (yr)')
# Out:
# flare 2
# flare 2
# Text(0, 0.5, 'Cooling time (yr)')

# %%
flare2_dict = {}

flare2_dict['peak_data'] = np.load(flare2_dir+'peak_data.npz')

flare2_dict['Lnu_3GHz'] = np.load(flare2_dir+'Lnu_3.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_10GHz'] = np.load(flare2_dir+'Lnu_10.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_15GHz'] = np.load(flare2_dir+'Lnu_15.00GHz_sparse_Te_1.0E+04.npz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_3GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ff_atfreq'],color='dodgerblue',label='flare2',ls=':')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ff}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e6)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_10GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_15GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,1e2)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =1e6 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_Lnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr']*365.25,3e9*flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr']*365.25,10e9*flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr']*365.25,15e9*flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [days]')
plt.ylabel(r'$\nu L_{\nu}$ [erg/s]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e30,1e40)
plt.xlim(1,1e5)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =1e6 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_nuLnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %% [markdown]
# ## for rho_ISM = 5e6e-24 g/cm^3

# %%
data_dir='./evolve_spectrum_epsB_1e-1/shell_evolution_rhoISM_5e+06e-24_cgs/'
# flare1_dir = data_dir+'/flare1/'
flare2_dir = data_dir+'/flare2/'

eps_B=0.1
eps_E=0.1

# %%
from astropy.constants import m_e, sigma_T, e, c
eps_B=0.1
eps_E=0.1

def B(eps_B,rho,vel): #inputs in CGS
    return np.sqrt(8*np.pi*eps_B*rho*vel**2) #in Gauss
#assuming gamma_max -> infty, normalization of dn/dgamma = n0 * gamma^-p is:
def n0(eps_E,gamma_min,rho,vel): #this is number density for the energy distribution dn/dgamma
    return eps_E*gamma_min*rho*vel**2/(m_e.cgs.value*c.cgs.value**2)
#usually assume gamma_min=1
#adopt p=3 also
dndgamma_func = lambda gamma,n0_const,p: n0_const*gamma**(-p)

dict_colors=['crimson','dodgerblue']
dict_linestyles=['-','-']
# datadir_list = []
dNdgamma_dir_list = []
# for key in dict_4p08M_paths.keys():
# data_dir='./evolve_spectrum_epsB_1e-2/shell_evolution_deltat_1yr/'
# dNdgamma_dir_list.append(flare1_dir)
# datadir_list.append('./evolve_spectrum_epsB_1e-2/')
dNdgamma_dir_list.append(flare2_dir)

shock_data = np.load(data_dir + 'shock_data.npz')
times = shock_data['times']
vsh_orig = shock_data['vsh_of_t']
rsh_of_t = shock_data['rsh_of_t']
rho_const = shock_data['rho_const']
rho2_of_t = shock_data['rho2_of_t']
# deltav1_of_t = shock_data['deltav1_of_t']
deltav2_of_t = shock_data['deltav2_of_t']

colors = ['crimson','dodgerblue']
# fig, ax = plt.subplots(3,1,figsize=(6,8),sharex=True)
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
for dNdgamma_dir in dNdgamma_dir_list:
    # if flare==0:
    #     rho_of_t = rho_const
    #     vsh_of_t = deltav1_of_t
    # elif flare==1:
    #     rho_of_t = rho2_of_t
    #     vsh_of_t = vsh_orig
    flare = 1
    rho_of_t = rho2_of_t
    vsh_of_t = vsh_orig
    print('flare',flare+1)
    print('flare',flare+1)
    # if key != 'fomega0p3':
    #     continue
    B_of_t = B(eps_B=eps_B,rho=rho_of_t,vel=vsh_of_t)
    gamma_cool = (100*(B_of_t/0.5)**(-2) * (rsh_of_t/vsh_orig/secinyear)**(-1))
    nu_cool = gamma_cool**2 * (1/2/np.pi)*e.gauss.value*B_of_t/(m_e.cgs.value*c.cgs.value)
    ax1.plot(times/secinyear,nu_cool/1e9)
    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_ylim(1e-2,1e14)
    ax1.set_ylabel('Frequency (GHz)')
    ax1.set_xlabel('Time (yr)')
    # plt.plot(times,B_of_t)

        # label1 = 'synchrotron cooling time'
    label2 = 'adiabatic cooling time'
    label1 = '3 GHz t_cool,syn'
    label3 = '10 GHz t_cool,syn'
    label4 = '15 GHz t_cool,syn'
    # plt.figure()
    ax2.plot(times/secinyear,t_cool_syn(3e9,B_of_t)/secinyear,label=label1,ls='--',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(10e9,B_of_t)/secinyear,label=label3,ls=':',color=colors[flare])
    ax2.plot(times/secinyear,t_cool_syn(15e9,B_of_t)/secinyear,label=label4,ls='-.',color=colors[flare])
    ax2.plot(times/secinyear, (rsh_of_t/vsh_orig)/secinyear,label=label2,color=colors[flare],zorder=1-flare)
ax2.legend()
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_xlim(1e-2,10)
# ax2.set_ylim(1e-3,100)
ax2.set_xlabel('Time (yr)')
ax2.set_ylabel('Cooling time (yr)')
# Out:
# flare 2
# flare 2
# /var/folders/88/vw5g86zs1sd9k55gz484chg00000gn/T/ipykernel_39230/2220959023.py:52: RuntimeWarning: divide by zero encountered in power
#   gamma_cool = (100*(B_of_t/0.5)**(-2) * (rsh_of_t/vsh_orig/secinyear)**(-1))
# /var/folders/88/vw5g86zs1sd9k55gz484chg00000gn/T/ipykernel_39230/2220959023.py:53: RuntimeWarning: invalid value encountered in multiply
#   nu_cool = gamma_cool**2 * (1/2/np.pi)*e.gauss.value*B_of_t/(m_e.cgs.value*c.cgs.value)
# /var/folders/88/vw5g86zs1sd9k55gz484chg00000gn/T/ipykernel_39230/31491928.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   return (3/sigma_T.cgs.value) * np.sqrt(2*np.pi*c.cgs.value*m_e.cgs.value*e.gauss.value/(B**3)) * nu**(-0.5)
# /var/folders/88/vw5g86zs1sd9k55gz484chg00000gn/T/ipykernel_39230/31491928.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   return (3/sigma_T.cgs.value) * np.sqrt(2*np.pi*c.cgs.value*m_e.cgs.value*e.gauss.value/(B**3)) * nu**(-0.5)
# ...

# %%
flare2_dict = {}

flare2_dict['peak_data'] = np.load(flare2_dir+'peak_data.npz')

flare2_dict['Lnu_3GHz'] = np.load(flare2_dir+'Lnu_3.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_10GHz'] = np.load(flare2_dir+'Lnu_10.00GHz_sparse_Te_1.0E+04.npz')

flare2_dict['Lnu_15GHz'] = np.load(flare2_dir+'Lnu_15.00GHz_sparse_Te_1.0E+04.npz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_3GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ff_atfreq'],color='dodgerblue',label='flare2',ls=':')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ff}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e6)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('3 GHz')
# Out:
# Text(0.5, 1.0, '3 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_10GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('10 GHz')
# Out:
# Text(0.5, 1.0, '10 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.savefig(data_dir+'powerlawISM_flare2_Lnu_15GHz.png',bbox_inches='tight',transparent=False,facecolor='white')
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['tau_ssa_atfreq'],color='dodgerblue',label='flare2')
plt.xlabel('Time [yr]')
plt.ylabel(r'$\tau_{ssa}$')
plt.xscale('log')
plt.yscale('log')
# plt.ylim(1e21,1e28)
plt.ylim(1e-10,1e4)
plt.xlim(1e-2,10)
plt.legend()
plt.grid()
plt.title('15 GHz')
# Out:
# Text(0.5, 1.0, '15 GHz')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr'],flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr'],flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr'],flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [yr]')
plt.ylabel(r'$L_{\nu}$ [erg/s/Hz]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e21,1e30)
plt.xlim(1e-2,1e2)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =1e6 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_Lnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')

# %%
plt.plot(flare2_dict['Lnu_3GHz']['times_yr']*365.25,3e9*flare2_dict['Lnu_3GHz']['Lnu_abs_atfreq'],color='crimson',label='3 GHz')
plt.plot(flare2_dict['Lnu_10GHz']['times_yr']*365.25,10e9*flare2_dict['Lnu_10GHz']['Lnu_abs_atfreq'],color='darkorange',label='10 GHz')
plt.plot(flare2_dict['Lnu_15GHz']['times_yr']*365.25,15e9*flare2_dict['Lnu_15GHz']['Lnu_abs_atfreq'],color='limegreen',label='15 GHz')
plt.xlabel('Time [days]')
plt.ylabel(r'$\nu L_{\nu}$ [erg/s]')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e30,1e40)
plt.xlim(1,1e5)
plt.legend()
plt.grid()
plt.title(r'$\rho_{\rm ISM} =1e6 \times 10^{-24}$ g/cm$^3$')
plt.savefig(data_dir+'flare2_nuLnu_diff_nus.png',bbox_inches='tight',transparent=False,facecolor='white')
